# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt2
import numpy as num
# %matplotlib inline

# %%
x=[0.00,1.00,2.00,3.00,4.00,5.00,6.00,7.00,8.00,9.00,10.00,11.00,12.00,13.00,14.00,15.00,16.00,17.00,18.00,19.00,20.00,21.00,22.00,23.00,24.00]
y=[(11878),(11513),(11157),(11070),(11291),(12120),(13696),(15583),(16283),(16545),(16885),(17120),(17263),(17043),(16711),(16756),(16311),(16497),(16636),(16823),(16704),(15780),(14561),(13544),(12625)]

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.set_title('Daily Load Curve (29.09.2021)')
ax.set_xlabel('Time (in 24h)')
ax.set_ylabel('Consumption(MWh)')
plt.plot(x,y)

# %%
x=[1.00,2.00,3.00,4.00,5.00,6.00,7.00,8.00,9.00,10.00,11.00,12.00,13.00,14.00,15.00,16.00,17.00,18.00,19.00,20.00,21.00,22.00,23.00,24.00,25.00]
y=[(17263),(17120),(17043),(16885),(16823),(16756),(16711),(16704),(16636),(16545),(16497),(16311),(16283),(15780),(15583),(14561),(13696),(13544),(12625),(12120),(11878),(11513),(11291),(11157),(11070)]

# %%
fig2=plt2.figure()
ax2=fig2.add_axes([0,0,1,1])
ax2.set_title('Load Duration Curve (29.09.2021)')
ax2.set_xlabel('Time(h)')
ax2.set_ylabel('Load(MWh)')
plt2.plot(x,y)
